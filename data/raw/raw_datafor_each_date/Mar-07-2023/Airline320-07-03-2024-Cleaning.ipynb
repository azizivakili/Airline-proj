# %%
import pandas as pd

# Your provided data
data = pd.read_csv("Airline-Fr320-07-03-2024-OK.csv")
print(data)
# Create a DataFrame
df = pd.DataFrame(data)

# Convert "Estimated Arrival Time" to minutes
df['Estimated Arrival Time'] = pd.to_timedelta(df['Estimated Arrival Time'])
df['EA_Time_Minutes'] = df['Estimated Arrival Time'].dt.total_seconds() / 60
# Print the result DataFrame
print(df)

df.to_csv("test1.csv")
# Out:
#    Aircraft Flight Type                                            Origin  \
# 0   AFL1234        A320                   Sheremetyevo Int'l (SVO / UUEE)
# 1   AFL1386        A320                              Near Nizhny Novgorod
# 2   AIQ3017        A320  Don Muang Int'l (Old Bangkok Int'l) (DMK / VTBD)
# 3    AXM239        A320                  Kota Kinabalu Int'l (BKI / WBKK)
# 4    AXM385        A320         Jakarta-Soekarno-Hatta Int'l (CGK / WIII)
# ..      ...         ...                                               ...
# 73   GBB209        A320                       OR Tambo Int'l (JNB / FAOR)
# 74   GPX810        A320                             Pristina (PRN / BKPR)
# 75  IBE3010        A320         Adolfo Suárez Madrid-Barajas (MAD / LEMD)
# 76   JST532        A320                Melbourne Tullamarine (MEL / YMML)
# 77   JST612        A320                               Avalon (AVV / YMAV)
#
#                         Destination    Departure Time      Arrival Time  \
# 0            Ufa Int'l (UFA / UWUU)   Fri 11:54AM MSK   Fri 03:15PM +05
# 1                               NaN   Fri 11:53AM MSK               NaN
# 2         Phuket Int'l (HKT / VTSP)   Fri 03:53PM +07   Fri 05:08PM +07
# 3      Hong Kong Int'l (HKG / VHHH)   Fri 04:54PM +08   Fri 07:44PM HKT
# 4   Kuala Lumpur Int'l (KUL / WMKK)   Fri 03:55PM WIB   Fri 06:45PM +08
# ..                              ...               ...               ...
# 73    King Shaka Int'l (DUR / FALE)  Fri 12:18PM SAST  Fri 12:56PM SAST
# 74      Basle-Mulhouse (EAP / LFSB)   Fri 11:20AM CET   Fri 01:00PM CET
# 75     Barcelona Int'l (BCN / LEBL)   Fri 11:21AM CET   Fri 12:21PM CET
# 76              Sydney (SYD / YSSY)  Fri 09:19PM AEDT  Fri 10:25PM AEDT
# 77              Sydney (SYD / YSSY)  Fri 09:19PM AEDT  Fri 10:25PM AEDT
#
#    Estimated Arrival Time RealArrivalTime
# 0                01:36:00          1h 31m
# 1                     NaN          0h 05m
# 2                01:15:00          1h 07m
# 3                02:50:00          2h 51m
# 4                01:50:00          1h 50m
# ..                    ...             ...
# 73               00:38:00          0h 48m
# 74               01:40:00          1h 40m
# 75               01:00:00          1h 10m
# 76               00:49:00          1h 16m
# 77               00:51:00          1h 16m
#
# [78 rows x 8 columns]
#    Aircraft Flight Type                                            Origin  \
# 0   AFL1234        A320                   Sheremetyevo Int'l (SVO / UUEE)
# 1   AFL1386        A320                              Near Nizhny Novgorod
# 2   AIQ3017        A320  Don Muang Int'l (Old Bangkok Int'l) (DMK / VTBD)
# 3    AXM239        A320                  Kota Kinabalu Int'l (BKI / WBKK)
# 4    AXM385        A320         Jakarta-Soekarno-Hatta Int'l (CGK / WIII)
# ..      ...         ...                                               ...
# 73   GBB209        A320                       OR Tambo Int'l (JNB / FAOR)
# 74   GPX810        A320                             Pristina (PRN / BKPR)
# 75  IBE3010        A320         Adolfo Suárez Madrid-Barajas (MAD / LEMD)
# 76   JST532        A320                Melbourne Tullamarine (MEL / YMML)
# 77   JST612        A320                               Avalon (AVV / YMAV)
#
#                         Destination    Departure Time      Arrival Time  \
# 0            Ufa Int'l (UFA / UWUU)   Fri 11:54AM MSK   Fri 03:15PM +05
# 1                               NaN   Fri 11:53AM MSK               NaN
# 2         Phuket Int'l (HKT / VTSP)   Fri 03:53PM +07   Fri 05:08PM +07
# 3      Hong Kong Int'l (HKG / VHHH)   Fri 04:54PM +08   Fri 07:44PM HKT
# 4   Kuala Lumpur Int'l (KUL / WMKK)   Fri 03:55PM WIB   Fri 06:45PM +08
# ..                              ...               ...               ...
# 73    King Shaka Int'l (DUR / FALE)  Fri 12:18PM SAST  Fri 12:56PM SAST
# 74      Basle-Mulhouse (EAP / LFSB)   Fri 11:20AM CET   Fri 01:00PM CET
# 75     Barcelona Int'l (BCN / LEBL)   Fri 11:21AM CET   Fri 12:21PM CET
# 76              Sydney (SYD / YSSY)  Fri 09:19PM AEDT  Fri 10:25PM AEDT
# 77              Sydney (SYD / YSSY)  Fri 09:19PM AEDT  Fri 10:25PM AEDT
#
#    Estimated Arrival Time RealArrivalTime  EA_Time_Minutes
# 0         0 days 01:36:00          1h 31m             96.0
# 1                     NaT          0h 05m              NaN
# 2         0 days 01:15:00          1h 07m             75.0
# 3         0 days 02:50:00          2h 51m            170.0
# 4         0 days 01:50:00          1h 50m            110.0
# ..                    ...             ...              ...
# 73        0 days 00:38:00          0h 48m             38.0
# 74        0 days 01:40:00          1h 40m            100.0
# 75        0 days 01:00:00          1h 10m             60.0
# 76        0 days 00:49:00          1h 16m             49.0
# 77        0 days 00:51:00          1h 16m             51.0
#
# [78 rows x 9 columns]

# %%
import pandas as pd

# Convert "RealArrivalTime" to minutes
df['RA_Time_Minutes'] = df['RealArrivalTime'].apply(lambda x: sum(int(i[:-1]) * (60 if i.endswith('h') else 1) for i in x.split()))



# Display the DataFrame
print(df)

df.to_csv("test2.csv")
# Out:
#    Aircraft Flight Type                                            Origin  \
# 0   AFL1234        A320                   Sheremetyevo Int'l (SVO / UUEE)
# 1   AFL1386        A320                              Near Nizhny Novgorod
# 2   AIQ3017        A320  Don Muang Int'l (Old Bangkok Int'l) (DMK / VTBD)
# 3    AXM239        A320                  Kota Kinabalu Int'l (BKI / WBKK)
# 4    AXM385        A320         Jakarta-Soekarno-Hatta Int'l (CGK / WIII)
# ..      ...         ...                                               ...
# 73   GBB209        A320                       OR Tambo Int'l (JNB / FAOR)
# 74   GPX810        A320                             Pristina (PRN / BKPR)
# 75  IBE3010        A320         Adolfo Suárez Madrid-Barajas (MAD / LEMD)
# 76   JST532        A320                Melbourne Tullamarine (MEL / YMML)
# 77   JST612        A320                               Avalon (AVV / YMAV)
#
#                         Destination    Departure Time      Arrival Time  \
# 0            Ufa Int'l (UFA / UWUU)   Fri 11:54AM MSK   Fri 03:15PM +05
# 1                               NaN   Fri 11:53AM MSK               NaN
# 2         Phuket Int'l (HKT / VTSP)   Fri 03:53PM +07   Fri 05:08PM +07
# 3      Hong Kong Int'l (HKG / VHHH)   Fri 04:54PM +08   Fri 07:44PM HKT
# 4   Kuala Lumpur Int'l (KUL / WMKK)   Fri 03:55PM WIB   Fri 06:45PM +08
# ..                              ...               ...               ...
# 73    King Shaka Int'l (DUR / FALE)  Fri 12:18PM SAST  Fri 12:56PM SAST
# 74      Basle-Mulhouse (EAP / LFSB)   Fri 11:20AM CET   Fri 01:00PM CET
# 75     Barcelona Int'l (BCN / LEBL)   Fri 11:21AM CET   Fri 12:21PM CET
# 76              Sydney (SYD / YSSY)  Fri 09:19PM AEDT  Fri 10:25PM AEDT
# 77              Sydney (SYD / YSSY)  Fri 09:19PM AEDT  Fri 10:25PM AEDT
#
#    Estimated Arrival Time RealArrivalTime  EA_Time_Minutes  RA_Time_Minutes
# 0         0 days 01:36:00          1h 31m             96.0               91
# 1                     NaT          0h 05m              NaN                5
# 2         0 days 01:15:00          1h 07m             75.0               67
# 3         0 days 02:50:00          2h 51m            170.0              171
# 4         0 days 01:50:00          1h 50m            110.0              110
# ..                    ...             ...              ...              ...
# 73        0 days 00:38:00          0h 48m             38.0               48
# 74        0 days 01:40:00          1h 40m            100.0              100
# 75        0 days 01:00:00          1h 10m             60.0               70
# 76        0 days 00:49:00          1h 16m             49.0               76
# 77        0 days 00:51:00          1h 16m             51.0               76
#
# [78 rows x 10 columns]

# %%
df.to_csv("test2.csv")

# %%
df['Delay_Time'] = df['RA_Time_Minutes'] - df['EA_Time_Minutes']

# %%
df.to_csv("Final_DataSet.csv")

# %%
df
# Out:
#    Aircraft Flight Type                                            Origin  \
# 0   AFL1234        A320                   Sheremetyevo Int'l (SVO / UUEE)
# 1   AFL1386        A320                              Near Nizhny Novgorod
# 2   AIQ3017        A320  Don Muang Int'l (Old Bangkok Int'l) (DMK / VTBD)
# 3    AXM239        A320                  Kota Kinabalu Int'l (BKI / WBKK)
# 4    AXM385        A320         Jakarta-Soekarno-Hatta Int'l (CGK / WIII)
# ..      ...         ...                                               ...
# 73   GBB209        A320                       OR Tambo Int'l (JNB / FAOR)
# 74   GPX810        A320                             Pristina (PRN / BKPR)
# 75  IBE3010        A320         Adolfo Suárez Madrid-Barajas (MAD / LEMD)
# 76   JST532        A320                Melbourne Tullamarine (MEL / YMML)
# 77   JST612        A320                               Avalon (AVV / YMAV)
#
#                         Destination    Departure Time      Arrival Time  \
# 0            Ufa Int'l (UFA / UWUU)   Fri 11:54AM MSK   Fri 03:15PM +05
# 1                               NaN   Fri 11:53AM MSK               NaN
# 2         Phuket Int'l (HKT / VTSP)   Fri 03:53PM +07   Fri 05:08PM +07
# 3      Hong Kong Int'l (HKG / VHHH)   Fri 04:54PM +08   Fri 07:44PM HKT
# 4   Kuala Lumpur Int'l (KUL / WMKK)   Fri 03:55PM WIB   Fri 06:45PM +08
# ..                              ...               ...               ...
# 73    King Shaka Int'l (DUR / FALE)  Fri 12:18PM SAST  Fri 12:56PM SAST
# 74      Basle-Mulhouse (EAP / LFSB)   Fri 11:20AM CET   Fri 01:00PM CET
# 75     Barcelona Int'l (BCN / LEBL)   Fri 11:21AM CET   Fri 12:21PM CET
# 76              Sydney (SYD / YSSY)  Fri 09:19PM AEDT  Fri 10:25PM AEDT
# 77              Sydney (SYD / YSSY)  Fri 09:19PM AEDT  Fri 10:25PM AEDT
#
#    Estimated Arrival Time RealArrivalTime  EA_Time_Minutes  RA_Time_Minutes  \
# 0         0 days 01:36:00          1h 31m             96.0               91
# 1                     NaT          0h 05m              NaN                5
# 2         0 days 01:15:00          1h 07m             75.0               67
# 3         0 days 02:50:00          2h 51m            170.0              171
# 4         0 days 01:50:00          1h 50m            110.0              110
# ..                    ...             ...              ...              ...
# 73        0 days 00:38:00          0h 48m             38.0               48
# 74        0 days 01:40:00          1h 40m            100.0              100
# 75        0 days 01:00:00          1h 10m             60.0               70
# 76        0 days 00:49:00          1h 16m             49.0               76
# 77        0 days 00:51:00          1h 16m             51.0               76
#
#     Delay_Time
# 0         -5.0
# 1          NaN
# 2         -8.0
# 3          1.0
# 4          0.0
# ..         ...
# 73        10.0
# 74         0.0
# 75        10.0
# 76        27.0
# 77        25.0
#
# [78 rows x 11 columns]
