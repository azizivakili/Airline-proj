# %%
import pandas as pd

# Your provided data
data = pd.read_csv("Airline-Fr320-07-03-2024-OK.csv")
print(data)
# Create a DataFrame
df = pd.DataFrame(data)

# Convert "Estimated Arrival Time" to minutes
df['Estimated Arrival Time'] = pd.to_timedelta(df['Estimated Arrival Time'])
df['EA_Time_Minutes'] = df['Estimated Arrival Time'].dt.total_seconds() / 60
# Print the result DataFrame
print(df)

df.to_csv("test1.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipykernel_53967/945389405.py in <module>
#       2
#       3 # Your provided data
# ----> 4 data = pd.read_csv("Airline-Fr320-07-03-2024-OK.csv")
#       5 print(data)
#       6 # Create a DataFrame
#
# ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1022     kwds.update(kwds_defaults)
#    1023
# -> 1024     return _read(filepath_or_buffer, kwds)
#    1025
#    1026
#
# ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     622
#     623     with parser:
# --> 624         return parser.read(nrows)
#     625
#     626
#
# ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1919                     columns,
#    1920                     col_dict,
# -> 1921                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1922                     nrows
#    1923                 )
#
# ~/.local/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     232         try:
#     233             if self.low_memory:
# --> 234                 chunks = self._reader.read_low_memory(nrows)
#     235                 # destructive to chunks
#     236                 data = _concatenate_chunks(chunks)
#
# parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 78, saw 2

# %%
import pandas as pd

# Convert "RealArrivalTime" to minutes
df['RA_Time_Minutes'] = df['RealArrivalTime'].apply(lambda x: sum(int(i[:-1]) * (60 if i.endswith('h') else 1) for i in x.split()))



# Display the DataFrame
print(df)

df.to_csv("test2.csv")
# Out:
#    Aircraft Flight Type                                            Origin  \
# 0    ABY221        A320                        Sharjah Int'l (SHJ / OMSJ)
# 1   AFL1387        A320       Ulyanovsk Baratayeveka Airport (ULV / UWLL)
# 2   AIQ3215        A320  Don Muang Int'l (Old Bangkok Int'l) (DMK / VTBD)
# 3   AIQ3557        A320                                  Nan (NNT / VTCN)
# 4   ARE4052        A320         Alfonso Bonilla Aragon Int'l (CLO / SKCL)
# ..      ...         ...                                               ...
# 77  UAL1035        A320                            Reagan National (KDCA)
# 78  VIV1057        A320  Don Miguel Hidalgo y Costilla Int'l (GDL / MMGL)
# 79  VIV4162        A320       General Mariano Escobedo Int'l (MTY / MMMY)
# 80  VLG8722        A320                      Barcelona Int'l (BCN / LEBL)
# 81   VTI563        A320             Chatrapati Shivaji Int'l (BOM / VABB)
#
#                                          Destination   Departure Time  \
# 0                      al-Jouf Domestic (AJF / OESK)  Fri 02:37PM +04
# 1                    Sheremetyevo Int'l (SVO / UUEE)  Fri 02:38PM +04
# 2                                 Krabi (KBV / VTSG)  Fri 05:37PM +07
# 3   Don Muang Int'l (Old Bangkok Int'l) (DMK / VTBD)  Fri 05:38PM +07
# 4                       El Dorado Int'l (BOG / SKBO)  Fri 05:37AM -05
# ..                                               ...              ...
# 77                        Chicago O'Hare Intl (KORD)  Fri 07:10AM EST
# 78             Lic. Benito Juarez Int'l (MEX / MMMX)  Fri 06:10AM CST
# 79         General Heriberto Jara Int'l (VER / MMVR)  Fri 06:10AM CST
# 80                         Dublin Int'l (DUB / EIDW)  Fri 01:10PM CET
# 81                    Jaipur (Sanganer) (JAI / VIJP)  Fri 05:38PM IST
#
#        Arrival Time Estimated Arrival Time RealArrivalTime  EA_Time_Minutes  \
# 0   Fri 04:12PM +03        0 days 02:35:00          2h 55m            155.0
# 1   Fri 02:58PM MSK        0 days 01:20:00          1h 30m             80.0
# 2   Fri 06:52PM +07        0 days 01:15:00          1h 15m             75.0
# 3   Fri 06:28PM +07        0 days 00:50:00          0h 50m             50.0
# 4   Fri 06:16AM -05        0 days 00:45:00          0h 40m             45.0
# ..              ...                    ...             ...              ...
# 77  Fri 07:55AM CST        0 days 01:50:00          2h 08m            110.0
# 78  Fri 07:15AM CST        0 days 01:05:00          1h 15m             65.0
# 79  Fri 07:25AM CST        0 days 01:15:00          1h 30m             75.0
# 80  Fri 02:38PM GMT        0 days 02:28:00          2h 48m            148.0
# 81  Fri 07:13PM IST        0 days 01:35:00          2h 04m             95.0
#
#     RA_Time_Minutes
# 0               175
# 1                90
# 2                75
# 3                50
# 4                40
# ..              ...
# 77              128
# 78               75
# 79               90
# 80              168
# 81              124
#
# [82 rows x 10 columns]

# %%
df.to_csv("test2.csv")

# %%
df['Delay_Time'] = df['RA_Time_Minutes'] - df['EA_Time_Minutes']

# %%
df.to_csv("Final_DataSet.csv")

# %%
df
# Out:
#    Aircraft Flight Type                                            Origin  \
# 0    ABY221        A320                        Sharjah Int'l (SHJ / OMSJ)
# 1   AFL1387        A320       Ulyanovsk Baratayeveka Airport (ULV / UWLL)
# 2   AIQ3215        A320  Don Muang Int'l (Old Bangkok Int'l) (DMK / VTBD)
# 3   AIQ3557        A320                                  Nan (NNT / VTCN)
# 4   ARE4052        A320         Alfonso Bonilla Aragon Int'l (CLO / SKCL)
# ..      ...         ...                                               ...
# 77  UAL1035        A320                            Reagan National (KDCA)
# 78  VIV1057        A320  Don Miguel Hidalgo y Costilla Int'l (GDL / MMGL)
# 79  VIV4162        A320       General Mariano Escobedo Int'l (MTY / MMMY)
# 80  VLG8722        A320                      Barcelona Int'l (BCN / LEBL)
# 81   VTI563        A320             Chatrapati Shivaji Int'l (BOM / VABB)
#
#                                          Destination   Departure Time  \
# 0                      al-Jouf Domestic (AJF / OESK)  Fri 02:37PM +04
# 1                    Sheremetyevo Int'l (SVO / UUEE)  Fri 02:38PM +04
# 2                                 Krabi (KBV / VTSG)  Fri 05:37PM +07
# 3   Don Muang Int'l (Old Bangkok Int'l) (DMK / VTBD)  Fri 05:38PM +07
# 4                       El Dorado Int'l (BOG / SKBO)  Fri 05:37AM -05
# ..                                               ...              ...
# 77                        Chicago O'Hare Intl (KORD)  Fri 07:10AM EST
# 78             Lic. Benito Juarez Int'l (MEX / MMMX)  Fri 06:10AM CST
# 79         General Heriberto Jara Int'l (VER / MMVR)  Fri 06:10AM CST
# 80                         Dublin Int'l (DUB / EIDW)  Fri 01:10PM CET
# 81                    Jaipur (Sanganer) (JAI / VIJP)  Fri 05:38PM IST
#
#        Arrival Time Estimated Arrival Time RealArrivalTime  EA_Time_Minutes  \
# 0   Fri 04:12PM +03        0 days 02:35:00          2h 55m            155.0
# 1   Fri 02:58PM MSK        0 days 01:20:00          1h 30m             80.0
# 2   Fri 06:52PM +07        0 days 01:15:00          1h 15m             75.0
# 3   Fri 06:28PM +07        0 days 00:50:00          0h 50m             50.0
# 4   Fri 06:16AM -05        0 days 00:45:00          0h 40m             45.0
# ..              ...                    ...             ...              ...
# 77  Fri 07:55AM CST        0 days 01:50:00          2h 08m            110.0
# 78  Fri 07:15AM CST        0 days 01:05:00          1h 15m             65.0
# 79  Fri 07:25AM CST        0 days 01:15:00          1h 30m             75.0
# 80  Fri 02:38PM GMT        0 days 02:28:00          2h 48m            148.0
# 81  Fri 07:13PM IST        0 days 01:35:00          2h 04m             95.0
#
#     RA_Time_Minutes  Delay_Time
# 0               175        20.0
# 1                90        10.0
# 2                75         0.0
# 3                50         0.0
# 4                40        -5.0
# ..              ...         ...
# 77              128        18.0
# 78               75        10.0
# 79               90        15.0
# 80              168        20.0
# 81              124        29.0
#
# [82 rows x 11 columns]
