# %%
import pandas as pd

# Your provided data
data = pd.read_csv("Airline-France-320-OK.csv")
print(data)
# Create a DataFrame
df = pd.DataFrame(data)

# Convert "Estimated Arrival Time" to minutes
df['Estimated Arrival Time'] = pd.to_timedelta(df['Estimated Arrival Time'])
df['EA_Time_Minutes'] = df['Estimated Arrival Time'].dt.total_seconds() / 60
# Print the result DataFrame
print(df)

df.to_csv("test1.csv")
# Out:
#    Aircraft Flight Type                                     Origin  \
# 0   AAY2839        A320                        Norfolk Intl (KORF)
# 1    AAY411        A320                Fort Lauderdale Intl (KFLL)
# 2    ABY552        A320                 Sharjah Int'l (SHJ / OMSJ)
# 3   AFR1384        A320      Charles de Gaulle/Roissy (CDG / LFPG)
# 4   AFR1748        A320      Charles de Gaulle/Roissy (CDG / LFPG)
# ..      ...         ...                                        ...
# 77   ANZ418        A320              Wellington Int'l (WLG / NZWN)
# 78  GAP2836        A320             Mactan-Cebu Int'l (CEB / RPVM)
# 79  PGT2206        A320  Istanbul Sabiha Gokcen Int'l (SAW / LTFJ)
# 80  TAM4511        A320            Campo Grande Int'l (CGR / SBCG)
# 81  GAP2557        A320                  Manila Int'l (MNL / RPLL)
#
#                                           Destination    Departure Time  \
# 0                         Orlando Sanford Intl (KSFB)   Mon 03:21PM EST
# 1   Cincinnati/Northern Kentucky International Air...   Mon 03:21PM EST
# 2                          Sialkot Int'l (SKT / OPST)   Tue 12:22AM +04
# 3                   Tunis-Carthage Int'l (TUN / DTTA)   Mon 09:21PM CET
# 4                                 Malaga (AGP / LEMG)   Mon 09:20PM CET
# ..                                                ...               ...
# 77                              Auckland (AKL / NZAA)  Tue 10:24AM NZDT
# 78                          Manila Int'l (MNL / RPLL)   Tue 05:24AM PST
# 79            İzmir Adnan Menderes Int'l (ADB / LTBJ)   Tue 12:24AM +03
# 80  Presidente Juscelino Kubitschek Int'l (BSB / S...   Mon 05:24PM -04
# 81                               Dipolog (DPL / RPMG)   Tue 05:23AM PST
#
#         Arrival Time Estimated Arrival Time RealArrivalTime
# 0    Mon 05:01PM EST               01:32:00          2h 02m
# 1    Mon 05:48PM EST               02:23:00          2h 52m
# 2    Tue 03:57AM PKT               02:35:00          2h 45m
# 3    Mon 11:29PM CET               02:07:00          2h 23m
# 4    Mon 11:51PM CET               02:29:00          2h 49m
# ..               ...                    ...             ...
# 77  Tue 11:16AM NZDT               00:42:00          0h 58m
# 78   Tue 06:29AM PST               01:05:00          1h 20m
# 79   Tue 01:00AM +03               00:55:00          1h 10m
# 80   Mon 07:25PM -03               01:10:00          1h 35m
# 81   Tue 06:09AM PST               01:10:00          1h 30m
#
# [82 rows x 8 columns]
#    Aircraft Flight Type                                     Origin  \
# 0   AAY2839        A320                        Norfolk Intl (KORF)
# 1    AAY411        A320                Fort Lauderdale Intl (KFLL)
# 2    ABY552        A320                 Sharjah Int'l (SHJ / OMSJ)
# 3   AFR1384        A320      Charles de Gaulle/Roissy (CDG / LFPG)
# 4   AFR1748        A320      Charles de Gaulle/Roissy (CDG / LFPG)
# ..      ...         ...                                        ...
# 77   ANZ418        A320              Wellington Int'l (WLG / NZWN)
# 78  GAP2836        A320             Mactan-Cebu Int'l (CEB / RPVM)
# 79  PGT2206        A320  Istanbul Sabiha Gokcen Int'l (SAW / LTFJ)
# 80  TAM4511        A320            Campo Grande Int'l (CGR / SBCG)
# 81  GAP2557        A320                  Manila Int'l (MNL / RPLL)
#
#                                           Destination    Departure Time  \
# 0                         Orlando Sanford Intl (KSFB)   Mon 03:21PM EST
# 1   Cincinnati/Northern Kentucky International Air...   Mon 03:21PM EST
# 2                          Sialkot Int'l (SKT / OPST)   Tue 12:22AM +04
# 3                   Tunis-Carthage Int'l (TUN / DTTA)   Mon 09:21PM CET
# 4                                 Malaga (AGP / LEMG)   Mon 09:20PM CET
# ..                                                ...               ...
# 77                              Auckland (AKL / NZAA)  Tue 10:24AM NZDT
# 78                          Manila Int'l (MNL / RPLL)   Tue 05:24AM PST
# 79            İzmir Adnan Menderes Int'l (ADB / LTBJ)   Tue 12:24AM +03
# 80  Presidente Juscelino Kubitschek Int'l (BSB / S...   Mon 05:24PM -04
# 81                               Dipolog (DPL / RPMG)   Tue 05:23AM PST
#
#         Arrival Time Estimated Arrival Time RealArrivalTime  EA_Time_Minutes
# 0    Mon 05:01PM EST        0 days 01:32:00          2h 02m             92.0
# 1    Mon 05:48PM EST        0 days 02:23:00          2h 52m            143.0
# 2    Tue 03:57AM PKT        0 days 02:35:00          2h 45m            155.0
# 3    Mon 11:29PM CET        0 days 02:07:00          2h 23m            127.0
# 4    Mon 11:51PM CET        0 days 02:29:00          2h 49m            149.0
# ..               ...                    ...             ...              ...
# 77  Tue 11:16AM NZDT        0 days 00:42:00          0h 58m             42.0
# 78   Tue 06:29AM PST        0 days 01:05:00          1h 20m             65.0
# 79   Tue 01:00AM +03        0 days 00:55:00          1h 10m             55.0
# 80   Mon 07:25PM -03        0 days 01:10:00          1h 35m             70.0
# 81   Tue 06:09AM PST        0 days 01:10:00          1h 30m             70.0
#
# [82 rows x 9 columns]
# /tmp/ipykernel_60109/3457241240.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import pandas as pd

# Convert "RealArrivalTime" to minutes
df['RA_Time_Minutes'] = df['RealArrivalTime'].apply(lambda x: sum(int(i[:-1]) * (60 if i.endswith('h') else 1) for i in x.split()))



# Display the DataFrame
print(df)

df.to_csv("test2.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_60109/2467801085.py in <module>
#       2
#       3 # Convert "RealArrivalTime" to minutes
# ----> 4 df['RA_Time_Minutes'] = df['RealArrivalTime'].apply(lambda x: sum(int(i[:-1]) * (60 if i.endswith('h') else 1) for i in x.split()))
#       5
#       6
#
# ~/.local/lib/python3.10/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4902             args=args,
#    4903             kwargs=kwargs,
# -> 4904         ).apply()
#    4905
#    4906     def _reindex_indexer(
#
# ~/.local/lib/python3.10/site-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# ~/.local/lib/python3.10/site-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
#    1506         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507         mapped = obj._map_values(
#    1508             mapper=curried, na_action=action, convert=self.convert_dtype
#    1509         )
#
# ~/.local/lib/python3.10/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action, convert)
#     919             return arr.map(mapper, na_action=na_action)
#     920
# --> 921         return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#     922
#     923     @final
#
# ~/.local/lib/python3.10/site-packages/pandas/core/algorithms.py in map_array(arr, mapper, na_action, convert)
#    1741     values = arr.astype(object, copy=False)
#    1742     if na_action is None:
# -> 1743         return lib.map_infer(values, mapper, convert=convert)
#    1744     else:
#    1745         return lib.map_infer_mask(
#
# lib.pyx in pandas._libs.lib.map_infer()
#
# /tmp/ipykernel_60109/2467801085.py in <lambda>(x)
#       2
#       3 # Convert "RealArrivalTime" to minutes
# ----> 4 df['RA_Time_Minutes'] = df['RealArrivalTime'].apply(lambda x: sum(int(i[:-1]) * (60 if i.endswith('h') else 1) for i in x.split()))
#       5
#       6
#
# /tmp/ipykernel_60109/2467801085.py in <genexpr>(.0)
#       2
#       3 # Convert "RealArrivalTime" to minutes
# ----> 4 df['RA_Time_Minutes'] = df['RealArrivalTime'].apply(lambda x: sum(int(i[:-1]) * (60 if i.endswith('h') else 1) for i in x.split()))
#       5
#       6
#
# ValueError: invalid literal for int() with base 10: '2h53'

# %%
df.to_csv("test2.csv")

# %%
df['Delay_Time'] = df['RA_Time_Minutes'] - df['EA_Time_Minutes']

# %%
df.to_csv("Final_DataSet.csv")

# %%
df
# Out:
#    Aircraft Flight Type                                      Origin  \
# 0    AEE121        A320  Thessaloniki Int'l, Makedonia (SKG / LGTS)
# 1   AFR1185        A320           Tunis-Carthage Int'l (TUN / DTTA)
# 2    ALK172        A320                Bengaluru Int'l (BLR / VOBL)
# 3   AVA8590        A320                El Dorado Int'l (BOG / SKBO)
# 4    AWQ109        A320                   Penang Int'l (PEN / WMKP)
# ..      ...         ...                                         ...
# 76  THY1845        A320               Istanbul Airport (IST / LTFM)
# 77  THY2612        A320               Istanbul Airport (IST / LTFM)
# 78  UAL2120        A320                          Denver Intl (KDEN)
# 79  VLG3916        A320                Barcelona Int'l (BCN / LEBL)
# 80   WAL522        A320                           Miami Intl (KMIA)
#
#                                           Destination   Departure Time  \
# 0    Athens Int'l, Eleftherios Venizelos (ATH / LGAV)  Wed 06:13PM EET
# 1               Charles de Gaulle/Roissy (CDG / LFPG)  Wed 05:13PM CET
# 2                     Bandaranaike Int'l (CMB / VCBI)  Wed 09:45PM IST
# 3                      Almirante Padilla (RCH / SKRH)  Wed 11:13AM -05
# 4               Kuala Namu International (KNO / WIMM)  Thu 12:13AM +08
# ..                                                ...              ...
# 76   Athens Int'l, Eleftherios Venizelos (ATH / LGAV)  Wed 07:57PM +03
# 77                            Diyarbakir (DIY / LTCC)  Wed 07:58PM +03
# 78                            New Orleans Intl (KMSY)  Wed 09:56AM MST
# 79  Palma de Mallorca (or Son Sant Joan) (PMI / LEPA)  Wed 05:58PM CET
# 80               Ignacio Agramonte Int'l (CMW / MUCM)  Wed 11:57AM EST
#
#          Arrival Time Estimated Arrival Time RealArrivalTime  EA_Time_Minutes  \
# 0     Wed 06:50PM EET        0 days 00:36:00          0h 47m             36.0
# 1     Wed 07:19PM CET        0 days 02:19:00          2h 35m            139.0
# 2   Wed 10:55PM +0530        0 days 01:10:00          1h 25m             70.0
# 3     Wed 12:29PM -05        0 days 01:16:00          1h 36m             76.0
# 4     Wed 11:43PM WIB        0 days 00:30:00          0h 30m             30.0
# ..                ...                    ...             ...              ...
# 76    Wed 08:05PM EET        0 days 01:10:00          1h 10m             70.0
# 77    Wed 09:33PM +03        0 days 01:35:00          1h 35m             95.0
# 78    Wed 12:59PM CST        0 days 02:03:00          2h 39m            123.0
# 79    Wed 06:32PM CET        0 days 00:33:00          0h 30m             33.0
# 80    Wed 12:47PM CST        0 days 00:50:00          0h 50m             50.0
#
#     RA_Time_Minutes  Delay_Time
# 0                47        11.0
# 1               155        16.0
# 2                85        15.0
# 3                96        20.0
# 4                30         0.0
# ..              ...         ...
# 76               70         0.0
# 77               95         0.0
# 78              159        36.0
# 79               30        -3.0
# 80               50         0.0
#
# [81 rows x 11 columns]
