# %%
import pandas as pd

# Your provided data
data = pd.read_csv("Mar-29-data.csv")
print(data)
# Create a DataFrame
df = pd.DataFrame(data)

# Convert "Estimated Arrival Time" to minutes
df['Estimated Arrival Time'] = pd.to_timedelta(df['Estimated Arrival Time'])
df['EA_Time'] = df['Estimated Arrival Time'].dt.total_seconds() / 60
# Print the result DataFrame
#print(df)

df.to_csv("EA_Time.csv")
# Out:
#      Unnamed: 0 Aircraft Flight Type  \
# 0             0  VLG6210        A320
# 1             1  JBU2795        A320
# 2             2  AVA8562        A320
# 3             3  ARE4015        A320
# 4             4  UAL1383        A320
# ..          ...      ...         ...
# 155         155  VOE2038        A320
# 156         156  VOE1134        A320
# 157         157  ARE4061        A320
# 158         158   AXM720        A320
# 159         159  DKH1076        A320
#
#                                                 Origin  \
# 0    Leonardo da Vinci Int'l (Fiumicino Int'l) (FCO...
# 1                          Fort Lauderdale Intl (KFLL)
# 2                          Antonio Narino (PSO / SKPS)
# 3                Jose Maria Cordova Int'l (MDE / SKRG)
# 4                          Houston Bush Int'ctl (KIAH)
# ..                                                 ...
# 155                                  Lyon (LYS / LFLL)
# 156                  Olbia-Costa Smeralda (OLB / LIEO)
# 157                       El Dorado Int'l (BOG / SKBO)
# 158                      Singapore Changi (SIN / WSSS)
# 159                Qingdao Jiaodong Int'l (TAO / ZSQD)
#
#                                    Destination   Departure Time  \
# 0                          Malaga (AGP / LEMG)  Fri 03:54PM CET
# 1                    Cancun Int'l (CUN / MMUN)  Fri 10:54AM EDT
# 2                                          NaN              NaN
# 3                 El Dorado Int'l (BOG / SKBO)  Fri 09:54AM -05
# 4                            John Wayne (KSNA)  Fri 09:54AM CDT
# ..                                         ...              ...
# 155          Václav Havel Airport (PRG / LKPR)  Fri 03:45PM CET
# 156                                        NaN              NaN
# 157  Alfonso Bonilla Aragon Int'l (CLO / SKCL)  Fri 09:45AM -05
# 158            Kuala Lumpur Int'l (KUL / WMKK)  Fri 10:45PM +08
# 159         Shanghai Pudong Int'l (PVG / ZSPD)  Fri 10:45PM CST
#
#         Arrival Time Estimated Arrival Time RealArrivalTime
# 0    Fri 06:19PM CET               02:25:00          2h 37m
# 1    Fri 11:47AM EST               01:53:00          2h 17m
# 2                NaN                    NaN             NaN
# 3    Fri 10:27AM -05               00:33:00          0h 49m
# 4    Fri 11:13AM PDT               03:19:00          3h 33m
# ..               ...                    ...             ...
# 155  Fri 05:00PM CET               01:20:00          1h 51m
# 156              NaN                    NaN             NaN
# 157  Fri 10:32AM -05               00:47:00          0h 37m
# 158  Fri 11:25PM +08               00:50:00           1h 3m
# 159  Fri 11:53PM CST               01:10:00          1h 49m
#
# [160 rows x 9 columns]
# /tmp/ipykernel_10760/1418893171.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Convert RealArrivalTime to Minutes. Eg: 3h 01m ->  181 min

def time_to_minutes(time_str):
    if pd.isna(time_str):
        return None
    else:
        hours, minutes = time_str.split('h ')
        hours = int(hours)
        minutes = int(minutes[:-1])  # Removing the 'm' from minutes
        return hours * 60 + minutes

# Apply the function to each row in the DataFrame
df['RA_Time'] = df['RealArrivalTime'].apply(time_to_minutes)
#df

# %%
df.to_csv("RA_Time.csv")

# %%
# Find Dealy_Time in minutes

df['Delay_Time'] = df['RA_Time'] - df['EA_Time']

# %%
# Extract Departure_Date form Departure Time

def convert_day_to_date(day):
    if day == 'Mon':
        return '04.03.2024'
    elif day == 'Tue':
        return '05.03.2024'
    elif day == 'Wed':
        return '06.03.2024'
    elif day == 'Thu':
        return '07.03.2024'
    elif day == 'Fri':
        return '08.03.2024'
    elif day == 'Sat':
        return '09.03.2024'
    elif day == 'Sun':
        return '10.03.2024'
    
df['Departure_Date'] = df['Departure Time'].str.split().str[0].apply(convert_day_to_date)
#df.to_csv("extract_dates.csv")
#df

# %%
# Extract Arrival_Date form Arrival Time

def convert_day_to_date(day):
    if day == 'Mon':
        return '04.03.2024'
    elif day == 'Tue':
        return '05.03.2024'
    elif day == 'Wed':
        return '06.03.2024'
    elif day == 'Thu':
        return '07.03.2024'
    elif day == 'Fri':
        return '08.03.2024'
    elif day == 'Sat':
        return '09.03.2024'
    elif day == 'Sun':
        return '10.03.2024'
    
df['Arrival_Date'] = df['Arrival Time'].str.split().str[0].apply(convert_day_to_date)
#df.to_csv("extract_dates.csv")
df.head()
# Out:
#    Unnamed: 0 Aircraft Flight Type  \
# 0           0  VLG6210        A320
# 1           1  JBU2795        A320
# 2           2  AVA8562        A320
# 3           3  ARE4015        A320
# 4           4  UAL1383        A320
#
#                                               Origin  \
# 0  Leonardo da Vinci Int'l (Fiumicino Int'l) (FCO...
# 1                        Fort Lauderdale Intl (KFLL)
# 2                        Antonio Narino (PSO / SKPS)
# 3              Jose Maria Cordova Int'l (MDE / SKRG)
# 4                        Houston Bush Int'ctl (KIAH)
#
#                     Destination   Departure Time     Arrival Time  \
# 0           Malaga (AGP / LEMG)  Fri 03:54PM CET  Fri 06:19PM CET
# 1     Cancun Int'l (CUN / MMUN)  Fri 10:54AM EDT  Fri 11:47AM EST
# 2                           NaN              NaN              NaN
# 3  El Dorado Int'l (BOG / SKBO)  Fri 09:54AM -05  Fri 10:27AM -05
# 4             John Wayne (KSNA)  Fri 09:54AM CDT  Fri 11:13AM PDT
#
#   Estimated Arrival Time RealArrivalTime  EA_Time  RA_Time  Delay_Time  \
# 0        0 days 02:25:00          2h 37m    145.0    157.0        12.0
# 1        0 days 01:53:00          2h 17m    113.0    137.0        24.0
# 2                    NaT             NaN      NaN      NaN         NaN
# 3        0 days 00:33:00          0h 49m     33.0     49.0        16.0
# 4        0 days 03:19:00          3h 33m    199.0    213.0        14.0
#
#   Departure_Date Arrival_Date
# 0     08.03.2024   08.03.2024
# 1     08.03.2024   08.03.2024
# 2           None         None
# 3     08.03.2024   08.03.2024
# 4     08.03.2024   08.03.2024

# %%
# Clean time in format of HH:MM AM/PM

df['Arrival_Time'] = df['Arrival Time'].str.extract(r'(\d{2}:\d{2}[AP]M)')
df['Departure_Time'] = df['Departure Time'].str.extract(r'(\d{2}:\d{2}[AP]M)')

# %%
# Clean time in format of 24 hours


df['Arrival_Time'] = pd.to_datetime(df['Arrival_Time']).dt.strftime('%H:%M')
df['Departure_Time'] = pd.to_datetime(df['Departure_Time']).dt.strftime('%H:%M')
df.head(3)
# Out:
# /tmp/ipykernel_10760/4013279808.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Arrival_Time'] = pd.to_datetime(df['Arrival_Time']).dt.strftime('%H:%M')
# /tmp/ipykernel_10760/4013279808.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Departure_Time'] = pd.to_datetime(df['Departure_Time']).dt.strftime('%H:%M')
#    Unnamed: 0 Aircraft Flight Type  \
# 0           0  VLG6210        A320
# 1           1  JBU2795        A320
# 2           2  AVA8562        A320
#
#                                               Origin  \
# 0  Leonardo da Vinci Int'l (Fiumicino Int'l) (FCO...
# 1                        Fort Lauderdale Intl (KFLL)
# 2                        Antonio Narino (PSO / SKPS)
#
#                  Destination   Departure Time     Arrival Time  \
# 0        Malaga (AGP / LEMG)  Fri 03:54PM CET  Fri 06:19PM CET
# 1  Cancun Int'l (CUN / MMUN)  Fri 10:54AM EDT  Fri 11:47AM EST
# 2                        NaN              NaN              NaN
#
#   Estimated Arrival Time RealArrivalTime  EA_Time  RA_Time  Delay_Time  \
# 0        0 days 02:25:00          2h 37m    145.0    157.0        12.0
# 1        0 days 01:53:00          2h 17m    113.0    137.0        24.0
# 2                    NaT             NaN      NaN      NaN         NaN
#
#   Departure_Date Arrival_Date Arrival_Time Departure_Time
# 0     08.03.2024   08.03.2024        18:19          15:54
# 1     08.03.2024   08.03.2024        11:47          10:54
# 2           None         None          NaN            NaN

# %%
df = df.drop(columns=['Departure Time', 'Arrival Time'])
df.head()
# Out:
#    Unnamed: 0 Aircraft Flight Type  \
# 0           0  VLG6210        A320
# 1           1  JBU2795        A320
# 2           2  AVA8562        A320
# 3           3  ARE4015        A320
# 4           4  UAL1383        A320
#
#                                               Origin  \
# 0  Leonardo da Vinci Int'l (Fiumicino Int'l) (FCO...
# 1                        Fort Lauderdale Intl (KFLL)
# 2                        Antonio Narino (PSO / SKPS)
# 3              Jose Maria Cordova Int'l (MDE / SKRG)
# 4                        Houston Bush Int'ctl (KIAH)
#
#                     Destination Estimated Arrival Time RealArrivalTime  \
# 0           Malaga (AGP / LEMG)        0 days 02:25:00          2h 37m
# 1     Cancun Int'l (CUN / MMUN)        0 days 01:53:00          2h 17m
# 2                           NaN                    NaT             NaN
# 3  El Dorado Int'l (BOG / SKBO)        0 days 00:33:00          0h 49m
# 4             John Wayne (KSNA)        0 days 03:19:00          3h 33m
#
#    EA_Time  RA_Time  Delay_Time Departure_Date Arrival_Date Arrival_Time  \
# 0    145.0    157.0        12.0     08.03.2024   08.03.2024        18:19
# 1    113.0    137.0        24.0     08.03.2024   08.03.2024        11:47
# 2      NaN      NaN         NaN           None         None          NaN
# 3     33.0     49.0        16.0     08.03.2024   08.03.2024        10:27
# 4    199.0    213.0        14.0     08.03.2024   08.03.2024        11:13
#
#   Departure_Time
# 0          15:54
# 1          10:54
# 2            NaN
# 3          09:54
# 4          09:54

# %%
# Re-structure the columns 

df = df[['Aircraft','Flight Type','Origin','Destination', 'Departure_Date', 'Departure_Time', 'Arrival_Date', 'Arrival_Time', 'EA_Time', 'RA_Time', 'Delay_Time']]
df
# Out:
#     Aircraft Flight Type                                             Origin  \
# 0    VLG6210        A320  Leonardo da Vinci Int'l (Fiumicino Int'l) (FCO...
# 1    JBU2795        A320                        Fort Lauderdale Intl (KFLL)
# 2    AVA8562        A320                        Antonio Narino (PSO / SKPS)
# 3    ARE4015        A320              Jose Maria Cordova Int'l (MDE / SKRG)
# 4    UAL1383        A320                        Houston Bush Int'ctl (KIAH)
# ..       ...         ...                                                ...
# 155  VOE2038        A320                                  Lyon (LYS / LFLL)
# 156  VOE1134        A320                  Olbia-Costa Smeralda (OLB / LIEO)
# 157  ARE4061        A320                       El Dorado Int'l (BOG / SKBO)
# 158   AXM720        A320                      Singapore Changi (SIN / WSSS)
# 159  DKH1076        A320                Qingdao Jiaodong Int'l (TAO / ZSQD)
#
#                                    Destination Departure_Date Departure_Time  \
# 0                          Malaga (AGP / LEMG)     08.03.2024          15:54
# 1                    Cancun Int'l (CUN / MMUN)     08.03.2024          10:54
# 2                                          NaN           None            NaN
# 3                 El Dorado Int'l (BOG / SKBO)     08.03.2024          09:54
# 4                            John Wayne (KSNA)     08.03.2024          09:54
# ..                                         ...            ...            ...
# 155          Václav Havel Airport (PRG / LKPR)     08.03.2024          15:45
# 156                                        NaN           None            NaN
# 157  Alfonso Bonilla Aragon Int'l (CLO / SKCL)     08.03.2024          09:45
# 158            Kuala Lumpur Int'l (KUL / WMKK)     08.03.2024          22:45
# 159         Shanghai Pudong Int'l (PVG / ZSPD)     08.03.2024          22:45
#
#     Arrival_Date Arrival_Time  EA_Time  RA_Time  Delay_Time
# 0     08.03.2024        18:19    145.0    157.0        12.0
# 1     08.03.2024        11:47    113.0    137.0        24.0
# 2           None          NaN      NaN      NaN         NaN
# 3     08.03.2024        10:27     33.0     49.0        16.0
# 4     08.03.2024        11:13    199.0    213.0        14.0
# ..           ...          ...      ...      ...         ...
# 155   08.03.2024        17:00     80.0    111.0        31.0
# 156         None          NaN      NaN      NaN         NaN
# 157   08.03.2024        10:32     47.0     37.0       -10.0
# 158   08.03.2024        23:25     50.0     63.0        13.0
# 159   08.03.2024        23:53     70.0    109.0        39.0
#
# [160 rows x 11 columns]

# %%
df.to_csv("Mar-29-Final_DataSet.csv")
