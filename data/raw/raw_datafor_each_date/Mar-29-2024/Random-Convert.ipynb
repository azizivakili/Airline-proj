# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# Sample data
data = pd.read_csv("Mar-29-today.csv")

# Create a DataFrame
df = pd.DataFrame(data)

# %%
df
# Out:
#     Aircraft Flight Type                                             Origin  \
# 0    VLG6210        A320  Leonardo da Vinci Int'l (Fiumicino Int'l) (FCO...
# 1    JBU2795        A320                        Fort Lauderdale Intl (KFLL)
# 2    AVA8562        A320                        Antonio Narino (PSO / SKPS)
# 3    ARE4015        A320              Jose Maria Cordova Int'l (MDE / SKRG)
# 4    UAL1383        A320                        Houston Bush Int'ctl (KIAH)
# ..       ...         ...                                                ...
# 155  VOE2038        A320                                  Lyon (LYS / LFLL)
# 156  VOE1134        A320                  Olbia-Costa Smeralda (OLB / LIEO)
# 157  ARE4061        A320                       El Dorado Int'l (BOG / SKBO)
# 158   AXM720        A320                      Singapore Changi (SIN / WSSS)
# 159  DKH1076        A320                Qingdao Jiaodong Int'l (TAO / ZSQD)
#
#                                    Destination   Departure Time  \
# 0                          Malaga (AGP / LEMG)  Fri 03:54PM CET
# 1                    Cancun Int'l (CUN / MMUN)  Fri 10:54AM EDT
# 2                                          NaN              NaN
# 3                 El Dorado Int'l (BOG / SKBO)  Fri 09:54AM -05
# 4                            John Wayne (KSNA)  Fri 09:54AM CDT
# ..                                         ...              ...
# 155          Václav Havel Airport (PRG / LKPR)  Fri 03:45PM CET
# 156                                        NaN              NaN
# 157  Alfonso Bonilla Aragon Int'l (CLO / SKCL)  Fri 09:45AM -05
# 158            Kuala Lumpur Int'l (KUL / WMKK)  Fri 10:45PM +08
# 159         Shanghai Pudong Int'l (PVG / ZSPD)  Fri 10:45PM CST
#
#         Arrival Time Estimated Arrival Time
# 0    Fri 06:19PM CET               02:25:00
# 1    Fri 11:47AM EST               01:53:00
# 2                NaN                    NaN
# 3    Fri 10:27AM -05               00:33:00
# 4    Fri 11:13AM PDT               03:19:00
# ..               ...                    ...
# 155  Fri 05:00PM CET               01:20:00
# 156              NaN                    NaN
# 157  Fri 10:32AM -05               00:47:00
# 158  Fri 11:25PM +08               00:50:00
# 159  Fri 11:53PM CST               01:10:00
#
# [160 rows x 7 columns]

# %%
# Create a DataFrame
df = pd.DataFrame(data)

# Convert string times to datetime objects
df['RealArrivalTime'] = pd.to_datetime(df['Estimated Arrival Time'], format='%H:%M:%S')

# Function to add random minutes between -20 to +50 minutes
def add_random_minutes(time):
    random_minutes = np.random.randint(-20, 51)  # Random integer between -20 to +50
    new_time = time + timedelta(minutes=random_minutes)
    return new_time

# Apply the function to the 'RealArrivalTime' column
df['RealArrivalTime'] = df['RealArrivalTime'].apply(add_random_minutes)

# Function to convert time to "Xh Ymin" format
def convert_to_hours_minutes(time):
    hours = time.hour
    minutes = time.minute
    return f"{hours}h {minutes}m"

# Apply the function to the 'RealArrivalTime' column
df['RealArrivalTime'] = df['RealArrivalTime'].apply(convert_to_hours_minutes)

# Print the DataFrame
print(df)
# Out:
#     Aircraft Flight Type                                             Origin  \
# 0    VLG6210        A320  Leonardo da Vinci Int'l (Fiumicino Int'l) (FCO...
# 1    JBU2795        A320                        Fort Lauderdale Intl (KFLL)
# 2    AVA8562        A320                        Antonio Narino (PSO / SKPS)
# 3    ARE4015        A320              Jose Maria Cordova Int'l (MDE / SKRG)
# 4    UAL1383        A320                        Houston Bush Int'ctl (KIAH)
# ..       ...         ...                                                ...
# 155  VOE2038        A320                                  Lyon (LYS / LFLL)
# 156  VOE1134        A320                  Olbia-Costa Smeralda (OLB / LIEO)
# 157  ARE4061        A320                       El Dorado Int'l (BOG / SKBO)
# 158   AXM720        A320                      Singapore Changi (SIN / WSSS)
# 159  DKH1076        A320                Qingdao Jiaodong Int'l (TAO / ZSQD)
#
#                                    Destination   Departure Time  \
# 0                          Malaga (AGP / LEMG)  Fri 03:54PM CET
# 1                    Cancun Int'l (CUN / MMUN)  Fri 10:54AM EDT
# 2                                          NaN              NaN
# 3                 El Dorado Int'l (BOG / SKBO)  Fri 09:54AM -05
# 4                            John Wayne (KSNA)  Fri 09:54AM CDT
# ..                                         ...              ...
# 155          Václav Havel Airport (PRG / LKPR)  Fri 03:45PM CET
# 156                                        NaN              NaN
# 157  Alfonso Bonilla Aragon Int'l (CLO / SKCL)  Fri 09:45AM -05
# 158            Kuala Lumpur Int'l (KUL / WMKK)  Fri 10:45PM +08
# 159         Shanghai Pudong Int'l (PVG / ZSPD)  Fri 10:45PM CST
#
#         Arrival Time Estimated Arrival Time RealArrivalTime
# 0    Fri 06:19PM CET               02:25:00          2h 37m
# 1    Fri 11:47AM EST               01:53:00          2h 17m
# 2                NaN                    NaN       nanh nanm
# 3    Fri 10:27AM -05               00:33:00          0h 49m
# 4    Fri 11:13AM PDT               03:19:00          3h 33m
# ..               ...                    ...             ...
# 155  Fri 05:00PM CET               01:20:00          1h 51m
# 156              NaN                    NaN       nanh nanm
# 157  Fri 10:32AM -05               00:47:00          0h 37m
# 158  Fri 11:25PM +08               00:50:00           1h 3m
# 159  Fri 11:53PM CST               01:10:00          1h 49m
#
# [160 rows x 8 columns]

# %%
df['RealArrivalTime'].replace('nanh nanm', '', inplace=True)
# Out:
# /tmp/ipykernel_44716/3532844304.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['RealArrivalTime'].replace('nanh nanm', '', inplace=True)

# %%
df.to_csv("Mar-29-data.csv")

# %%
df
# Out:
#     Aircraft Flight Type                                             Origin  \
# 0    VLG6210        A320  Leonardo da Vinci Int'l (Fiumicino Int'l) (FCO...
# 1    JBU2795        A320                        Fort Lauderdale Intl (KFLL)
# 2    AVA8562        A320                        Antonio Narino (PSO / SKPS)
# 3    ARE4015        A320              Jose Maria Cordova Int'l (MDE / SKRG)
# 4    UAL1383        A320                        Houston Bush Int'ctl (KIAH)
# ..       ...         ...                                                ...
# 155  VOE2038        A320                                  Lyon (LYS / LFLL)
# 156  VOE1134        A320                  Olbia-Costa Smeralda (OLB / LIEO)
# 157  ARE4061        A320                       El Dorado Int'l (BOG / SKBO)
# 158   AXM720        A320                      Singapore Changi (SIN / WSSS)
# 159  DKH1076        A320                Qingdao Jiaodong Int'l (TAO / ZSQD)
#
#                                    Destination   Departure Time  \
# 0                          Malaga (AGP / LEMG)  Fri 03:54PM CET
# 1                    Cancun Int'l (CUN / MMUN)  Fri 10:54AM EDT
# 2                                          NaN              NaN
# 3                 El Dorado Int'l (BOG / SKBO)  Fri 09:54AM -05
# 4                            John Wayne (KSNA)  Fri 09:54AM CDT
# ..                                         ...              ...
# 155          Václav Havel Airport (PRG / LKPR)  Fri 03:45PM CET
# 156                                        NaN              NaN
# 157  Alfonso Bonilla Aragon Int'l (CLO / SKCL)  Fri 09:45AM -05
# 158            Kuala Lumpur Int'l (KUL / WMKK)  Fri 10:45PM +08
# 159         Shanghai Pudong Int'l (PVG / ZSPD)  Fri 10:45PM CST
#
#         Arrival Time Estimated Arrival Time RealArrivalTime
# 0    Fri 06:19PM CET               02:25:00          2h 37m
# 1    Fri 11:47AM EST               01:53:00          2h 17m
# 2                NaN                    NaN
# 3    Fri 10:27AM -05               00:33:00          0h 49m
# 4    Fri 11:13AM PDT               03:19:00          3h 33m
# ..               ...                    ...             ...
# 155  Fri 05:00PM CET               01:20:00          1h 51m
# 156              NaN                    NaN
# 157  Fri 10:32AM -05               00:47:00          0h 37m
# 158  Fri 11:25PM +08               00:50:00           1h 3m
# 159  Fri 11:53PM CST               01:10:00          1h 49m
#
# [160 rows x 8 columns]
