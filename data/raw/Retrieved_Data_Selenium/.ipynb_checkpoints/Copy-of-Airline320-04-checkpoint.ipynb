# %%
import pandas as pd
#pd.set_option('max_columns', 200)

data = pd.read_csv("Airline_Fr320-Mar04-Mar09-2024.csv")
df = pd.DataFrame(data)
df
# Out:
#     Aircraft Flight Type                                        Origin  \
# 0    AAY2839        A320                           Norfolk Intl (KORF)
# 1     AAY411        A320                   Fort Lauderdale Intl (KFLL)
# 2     ABY552        A320                    Sharjah Int'l (SHJ / OMSJ)
# 3    AFR1384        A320         Charles de Gaulle/Roissy (CDG / LFPG)
# 4    AFR1748        A320         Charles de Gaulle/Roissy (CDG / LFPG)
# ..       ...         ...                                           ...
# 486   RZO175        A320                   Porto / Oporto (OPO / LPPR)
# 487  VOI1035        A320  Mexico City Santa Lucía Airport (NLU / MMSM)
# 488   VOI499        A320       Del Bajio Guanajuato Int'l (BJX / MMLO)
# 489   VOI924        A320    Lic. Jesus Teran Peredo Int'l (AGU / MMAS)
# 490   VOI967        A320                        Harry Reid Intl (KLAS)
#
#                                            Destination   Departure Time  \
# 0                          Orlando Sanford Intl (KSFB)  Mon 03:21PM EST
# 1    Cincinnati/Northern Kentucky International Air...  Mon 03:21PM EST
# 2                           Sialkot Int'l (SKT / OPST)  Tue 12:22AM +04
# 3                    Tunis-Carthage Int'l (TUN / DTTA)  Mon 09:21PM CET
# 4                                  Malaga (AGP / LEMG)  Mon 09:20PM CET
# ..                                                 ...              ...
# 486           Ponta Delgada Joao Paulo II (PDL / LPPD)  Sat 10:04PM WET
# 487   Don Miguel Hidalgo y Costilla Int'l (GDL / MMGL)  Sat 04:06PM CST
# 488   General Abelardo L. Rodriguez Int'l (TIJ / MMTJ)  Sat 04:04PM CST
# 489                            Los Angeles Intl (KLAX)  Sat 04:05PM CST
# 490              Lic. Benito Juarez Int'l (MEX / MMMX)  Sat 02:04PM PST
#
#         Arrival Time Estimated Arrival Time RealArrivalTime
# 0    Mon 05:01PM EST               01:32:00          2h 02m
# 1    Mon 05:48PM EST               02:23:00          2h 52m
# 2    Tue 03:57AM PKT               02:35:00          2h 45m
# 3    Mon 11:29PM CET               02:07:00          2h 23m
# 4    Mon 11:51PM CET               02:29:00          2h 49m
# ..               ...                    ...             ...
# 486  Sat 11:15PM -01               02:10:00          2h 30m
# 487  Sat 05:15PM CST               01:09:00          1h 19m
# 488  Sat 04:54PM PST               02:47:00          3h 11m
# 489  Sat 04:45PM PST               02:40:00          3h 00m
# 490  Sat 07:25PM CST               03:17:00          3h 53m
#
# [491 rows x 8 columns]

# %%
# Columns info
df.count()
# Out:
# Aircraft                  491
# Flight Type               491
# Origin                    491
# Destination               481
# Departure Time            491
# Arrival Time              481
# Estimated Arrival Time    481
# RealArrivalTime           491
# dtype: int64

# %%
# show the rows and columns
df.shape
# Out:
# (491, 8)

# %%
df.describe()
# Out:
#        Aircraft Flight Type                        Origin  \
# count       491         491                           491
# unique      485           1                           257
# top      ANZ418        A320  El Dorado Int'l (BOG / SKBO)
# freq          2         491                            18
#
#                          Destination   Departure Time     Arrival Time  \
# count                            481              491              481
# unique                           270              383              469
# top     El Dorado Int'l (BOG / SKBO)  Mon 09:21PM CET  Tue 05:23PM EST
# freq                              18                8                3
#
#        Estimated Arrival Time RealArrivalTime
# count                     481             491
# unique                    172             178
# top                  00:45:00          1h 15m
# freq                       18              15

# %%
df.columns
# Out:
# Index(['Aircraft', 'Flight Type', 'Origin', 'Destination', 'Departure Time',
#        'Arrival Time', 'Estimated Arrival Time', 'RealArrivalTime'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Aircraft                  object
# Flight Type               object
# Origin                    object
# Destination               object
# Departure Time            object
# Arrival Time              object
# Estimated Arrival Time    object
# RealArrivalTime           object
# dtype: object

# %%
#show null or missing values 
#df.isna()
df.isna().sum()
# Out:
# Aircraft                  0
# Flight Type               0
# Origin                    0
# Destination               9
# Departure Date            0
# Departure_Time            0
# Arrival Date              9
# Arrival_Time              9
# Estimated Arrival Time    9
# RealArrivalTime           0
# dtype: int64

# %%
#df.loc[df.duplicated()]
df.duplicated(subset = ['Destination'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 486    False
# 487     True
# 488     True
# 489    False
# 490     True
# Length: 488, dtype: bool

# %%
# Data cleaning  /                       checked for no duplicate
df = df.drop_duplicates()
df
# Out:
#     Aircraft Flight Type                                        Origin  \
# 0    AAY2839        A320                           Norfolk Intl (KORF)
# 1     AAY411        A320                   Fort Lauderdale Intl (KFLL)
# 2     ABY552        A320                    Sharjah Int'l (SHJ / OMSJ)
# 3    AFR1384        A320         Charles de Gaulle/Roissy (CDG / LFPG)
# 4    AFR1748        A320         Charles de Gaulle/Roissy (CDG / LFPG)
# ..       ...         ...                                           ...
# 486   RZO175        A320                   Porto / Oporto (OPO / LPPR)
# 487  VOI1035        A320  Mexico City Santa Lucía Airport (NLU / MMSM)
# 488   VOI499        A320       Del Bajio Guanajuato Int'l (BJX / MMLO)
# 489   VOI924        A320    Lic. Jesus Teran Peredo Int'l (AGU / MMAS)
# 490   VOI967        A320                        Harry Reid Intl (KLAS)
#
#                                            Destination   Departure Time  \
# 0                          Orlando Sanford Intl (KSFB)  Mon 03:21PM EST
# 1    Cincinnati/Northern Kentucky International Air...  Mon 03:21PM EST
# 2                           Sialkot Int'l (SKT / OPST)  Tue 12:22AM +04
# 3                    Tunis-Carthage Int'l (TUN / DTTA)  Mon 09:21PM CET
# 4                                  Malaga (AGP / LEMG)  Mon 09:20PM CET
# ..                                                 ...              ...
# 486           Ponta Delgada Joao Paulo II (PDL / LPPD)  Sat 10:04PM WET
# 487   Don Miguel Hidalgo y Costilla Int'l (GDL / MMGL)  Sat 04:06PM CST
# 488   General Abelardo L. Rodriguez Int'l (TIJ / MMTJ)  Sat 04:04PM CST
# 489                            Los Angeles Intl (KLAX)  Sat 04:05PM CST
# 490              Lic. Benito Juarez Int'l (MEX / MMMX)  Sat 02:04PM PST
#
#         Arrival Time Estimated Arrival Time RealArrivalTime
# 0    Mon 05:01PM EST               01:32:00          2h 02m
# 1    Mon 05:48PM EST               02:23:00          2h 52m
# 2    Tue 03:57AM PKT               02:35:00          2h 45m
# 3    Mon 11:29PM CET               02:07:00          2h 23m
# 4    Mon 11:51PM CET               02:29:00          2h 49m
# ..               ...                    ...             ...
# 486  Sat 11:15PM -01               02:10:00          2h 30m
# 487  Sat 05:15PM CST               01:09:00          1h 19m
# 488  Sat 04:54PM PST               02:47:00          3h 11m
# 489  Sat 04:45PM PST               02:40:00          3h 00m
# 490  Sat 07:25PM CST               03:17:00          3h 53m
#
# [489 rows x 8 columns]

# %%
# delete the following row  
df = df[df['Aircraft'] != 'XLE903']
#show null values 
df[df.isnull().any(axis=1)]

#df.reset_index(drop = True).copy()

# %%
days_to_dates = {
    "Mon": "04.03.2024",
    "Tue": "05.03.2024", 
    "Wed": "06.03.2024",
    "Thu": "07.03.2024",
    "Fri": "08.03.2024",
    "Sat": "09.03.2024", 
    "Sun": "10.03.2024"
}

# Process "Departure Time" and "Arrival Time" columns
df['Departure Date'] = df['Departure Time'].apply(lambda x: days_to_dates[x.split()[0]] if x.split()[0] in days_to_dates else x)
df
# Out:
#     Aircraft Flight Type                                        Origin  \
# 0    AAY2839        A320                           Norfolk Intl (KORF)
# 1     AAY411        A320                   Fort Lauderdale Intl (KFLL)
# 2     ABY552        A320                    Sharjah Int'l (SHJ / OMSJ)
# 3    AFR1384        A320         Charles de Gaulle/Roissy (CDG / LFPG)
# 4    AFR1748        A320         Charles de Gaulle/Roissy (CDG / LFPG)
# ..       ...         ...                                           ...
# 486   RZO175        A320                   Porto / Oporto (OPO / LPPR)
# 487  VOI1035        A320  Mexico City Santa Lucía Airport (NLU / MMSM)
# 488   VOI499        A320       Del Bajio Guanajuato Int'l (BJX / MMLO)
# 489   VOI924        A320    Lic. Jesus Teran Peredo Int'l (AGU / MMAS)
# 490   VOI967        A320                        Harry Reid Intl (KLAS)
#
#                                            Destination   Departure Time  \
# 0                          Orlando Sanford Intl (KSFB)  Mon 03:21PM EST
# 1    Cincinnati/Northern Kentucky International Air...  Mon 03:21PM EST
# 2                           Sialkot Int'l (SKT / OPST)  Tue 12:22AM +04
# 3                    Tunis-Carthage Int'l (TUN / DTTA)  Mon 09:21PM CET
# 4                                  Malaga (AGP / LEMG)  Mon 09:20PM CET
# ..                                                 ...              ...
# 486           Ponta Delgada Joao Paulo II (PDL / LPPD)  Sat 10:04PM WET
# 487   Don Miguel Hidalgo y Costilla Int'l (GDL / MMGL)  Sat 04:06PM CST
# 488   General Abelardo L. Rodriguez Int'l (TIJ / MMTJ)  Sat 04:04PM CST
# 489                            Los Angeles Intl (KLAX)  Sat 04:05PM CST
# 490              Lic. Benito Juarez Int'l (MEX / MMMX)  Sat 02:04PM PST
#
#         Arrival Time Estimated Arrival Time RealArrivalTime Departure Date
# 0    Mon 05:01PM EST               01:32:00          2h 02m     04.03.2024
# 1    Mon 05:48PM EST               02:23:00          2h 52m     04.03.2024
# 2    Tue 03:57AM PKT               02:35:00          2h 45m     05.03.2024
# 3    Mon 11:29PM CET               02:07:00          2h 23m     04.03.2024
# 4    Mon 11:51PM CET               02:29:00          2h 49m     04.03.2024
# ..               ...                    ...             ...            ...
# 486  Sat 11:15PM -01               02:10:00          2h 30m     09.03.2024
# 487  Sat 05:15PM CST               01:09:00          1h 19m     09.03.2024
# 488  Sat 04:54PM PST               02:47:00          3h 11m     09.03.2024
# 489  Sat 04:45PM PST               02:40:00          3h 00m     09.03.2024
# 490  Sat 07:25PM CST               03:17:00          3h 53m     09.03.2024
#
# [491 rows x 9 columns]

# %%
def convert_day_to_date(day):
    if day == 'Mon':
        return '04.03.2024'
    elif day == 'Tue':
        return '05.03.2024'
    elif day == 'Wed':
        return '06.03.2024'
    elif day == 'Thu':
        return '07.03.2024'
    elif day == 'Fri':
        return '08.03.2024'
    elif day == 'Sat':
        return '09.03.2024'
    elif day == 'Sun':
        return '10.03.2024'
    
df['Arrival Date'] = df['Arrival Time'].str.split().str[0].apply(convert_day_to_date)
df.to_csv("extract_dates.csv")
df
# Out:
#     Aircraft Flight Type                                        Origin  \
# 0    AAY2839        A320                           Norfolk Intl (KORF)
# 1     AAY411        A320                   Fort Lauderdale Intl (KFLL)
# 2     ABY552        A320                    Sharjah Int'l (SHJ / OMSJ)
# 3    AFR1384        A320         Charles de Gaulle/Roissy (CDG / LFPG)
# 4    AFR1748        A320         Charles de Gaulle/Roissy (CDG / LFPG)
# ..       ...         ...                                           ...
# 486   RZO175        A320                   Porto / Oporto (OPO / LPPR)
# 487  VOI1035        A320  Mexico City Santa Lucía Airport (NLU / MMSM)
# 488   VOI499        A320       Del Bajio Guanajuato Int'l (BJX / MMLO)
# 489   VOI924        A320    Lic. Jesus Teran Peredo Int'l (AGU / MMAS)
# 490   VOI967        A320                        Harry Reid Intl (KLAS)
#
#                                            Destination   Departure Time  \
# 0                          Orlando Sanford Intl (KSFB)  Mon 03:21PM EST
# 1    Cincinnati/Northern Kentucky International Air...  Mon 03:21PM EST
# 2                           Sialkot Int'l (SKT / OPST)  Tue 12:22AM +04
# 3                    Tunis-Carthage Int'l (TUN / DTTA)  Mon 09:21PM CET
# 4                                  Malaga (AGP / LEMG)  Mon 09:20PM CET
# ..                                                 ...              ...
# 486           Ponta Delgada Joao Paulo II (PDL / LPPD)  Sat 10:04PM WET
# 487   Don Miguel Hidalgo y Costilla Int'l (GDL / MMGL)  Sat 04:06PM CST
# 488   General Abelardo L. Rodriguez Int'l (TIJ / MMTJ)  Sat 04:04PM CST
# 489                            Los Angeles Intl (KLAX)  Sat 04:05PM CST
# 490              Lic. Benito Juarez Int'l (MEX / MMMX)  Sat 02:04PM PST
#
#         Arrival Time Estimated Arrival Time RealArrivalTime Departure Date  \
# 0    Mon 05:01PM EST               01:32:00          2h 02m     04.03.2024
# 1    Mon 05:48PM EST               02:23:00          2h 52m     04.03.2024
# 2    Tue 03:57AM PKT               02:35:00          2h 45m     05.03.2024
# 3    Mon 11:29PM CET               02:07:00          2h 23m     04.03.2024
# 4    Mon 11:51PM CET               02:29:00          2h 49m     04.03.2024
# ..               ...                    ...             ...            ...
# 486  Sat 11:15PM -01               02:10:00          2h 30m     09.03.2024
# 487  Sat 05:15PM CST               01:09:00          1h 19m     09.03.2024
# 488  Sat 04:54PM PST               02:47:00          3h 11m     09.03.2024
# 489  Sat 04:45PM PST               02:40:00          3h 00m     09.03.2024
# 490  Sat 07:25PM CST               03:17:00          3h 53m     09.03.2024
#
#     Arrival Date
# 0     04.03.2024
# 1     04.03.2024
# 2     05.03.2024
# 3     04.03.2024
# 4     04.03.2024
# ..           ...
# 486   09.03.2024
# 487   09.03.2024
# 488   09.03.2024
# 489   09.03.2024
# 490   09.03.2024
#
# [491 rows x 10 columns]

# %%
df = df[['Aircraft','Flight Type','Origin',
'Destination', 'Departure Date', 'Departure Time', 'Arrival Date', 'Arrival Time', 'Estimated Arrival Time', 'RealArrivalTime']]
df
# Out:
#     Aircraft Flight Type                                        Origin  \
# 0    AAY2839        A320                           Norfolk Intl (KORF)
# 1     AAY411        A320                   Fort Lauderdale Intl (KFLL)
# 2     ABY552        A320                    Sharjah Int'l (SHJ / OMSJ)
# 3    AFR1384        A320         Charles de Gaulle/Roissy (CDG / LFPG)
# 4    AFR1748        A320         Charles de Gaulle/Roissy (CDG / LFPG)
# ..       ...         ...                                           ...
# 486   RZO175        A320                   Porto / Oporto (OPO / LPPR)
# 487  VOI1035        A320  Mexico City Santa Lucía Airport (NLU / MMSM)
# 488   VOI499        A320       Del Bajio Guanajuato Int'l (BJX / MMLO)
# 489   VOI924        A320    Lic. Jesus Teran Peredo Int'l (AGU / MMAS)
# 490   VOI967        A320                        Harry Reid Intl (KLAS)
#
#                                            Destination Departure Date  \
# 0                          Orlando Sanford Intl (KSFB)     04.03.2024
# 1    Cincinnati/Northern Kentucky International Air...     04.03.2024
# 2                           Sialkot Int'l (SKT / OPST)     05.03.2024
# 3                    Tunis-Carthage Int'l (TUN / DTTA)     04.03.2024
# 4                                  Malaga (AGP / LEMG)     04.03.2024
# ..                                                 ...            ...
# 486           Ponta Delgada Joao Paulo II (PDL / LPPD)     09.03.2024
# 487   Don Miguel Hidalgo y Costilla Int'l (GDL / MMGL)     09.03.2024
# 488   General Abelardo L. Rodriguez Int'l (TIJ / MMTJ)     09.03.2024
# 489                            Los Angeles Intl (KLAX)     09.03.2024
# 490              Lic. Benito Juarez Int'l (MEX / MMMX)     09.03.2024
#
#       Departure Time Arrival Date     Arrival Time Estimated Arrival Time  \
# 0    Mon 03:21PM EST   04.03.2024  Mon 05:01PM EST               01:32:00
# 1    Mon 03:21PM EST   04.03.2024  Mon 05:48PM EST               02:23:00
# 2    Tue 12:22AM +04   05.03.2024  Tue 03:57AM PKT               02:35:00
# 3    Mon 09:21PM CET   04.03.2024  Mon 11:29PM CET               02:07:00
# 4    Mon 09:20PM CET   04.03.2024  Mon 11:51PM CET               02:29:00
# ..               ...          ...              ...                    ...
# 486  Sat 10:04PM WET   09.03.2024  Sat 11:15PM -01               02:10:00
# 487  Sat 04:06PM CST   09.03.2024  Sat 05:15PM CST               01:09:00
# 488  Sat 04:04PM CST   09.03.2024  Sat 04:54PM PST               02:47:00
# 489  Sat 04:05PM CST   09.03.2024  Sat 04:45PM PST               02:40:00
# 490  Sat 02:04PM PST   09.03.2024  Sat 07:25PM CST               03:17:00
#
#     RealArrivalTime
# 0            2h 02m
# 1            2h 52m
# 2            2h 45m
# 3            2h 23m
# 4            2h 49m
# ..              ...
# 486          2h 30m
# 487          1h 19m
# 488          3h 11m
# 489          3h 00m
# 490          3h 53m
#
# [491 rows x 10 columns]

# %%
df['Departure_Time'] = df['Departure Time'].str.extract(r'(\d+:\d+[APMapm]+)')
df.head(3)
# Out:
# /tmp/ipykernel_28651/4169333212.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Departure_Time'] = df['Departure Time'].str.extract(r'(\d+:\d+[APMapm]+)')
#   Aircraft Flight Type                       Origin  \
# 0  AAY2839        A320          Norfolk Intl (KORF)
# 1   AAY411        A320  Fort Lauderdale Intl (KFLL)
# 2   ABY552        A320   Sharjah Int'l (SHJ / OMSJ)
#
#                                          Destination Departure Date  \
# 0                        Orlando Sanford Intl (KSFB)     04.03.2024
# 1  Cincinnati/Northern Kentucky International Air...     04.03.2024
# 2                         Sialkot Int'l (SKT / OPST)     05.03.2024
#
#     Departure Time Arrival Date     Arrival Time Estimated Arrival Time  \
# 0  Mon 03:21PM EST   04.03.2024  Mon 05:01PM EST               01:32:00
# 1  Mon 03:21PM EST   04.03.2024  Mon 05:48PM EST               02:23:00
# 2  Tue 12:22AM +04   05.03.2024  Tue 03:57AM PKT               02:35:00
#
#   RealArrivalTime Departure_Time Arrival_Time
# 0          2h 02m        03:21PM      05:01PM
# 1          2h 52m        03:21PM      05:48PM
# 2          2h 45m        12:22AM      03:57AM

# %%
#Regex 
df['Arrival_Time'] = df['Arrival Time'].str.extract(r'(\d+:\d+[APMapm]+)')
df.head(3)
# Out:
# /tmp/ipykernel_28651/2876227389.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Arrival_Time'] = df['Arrival Time'].str.extract(r'(\d+:\d+[APMapm]+)')
#   Aircraft Flight Type                       Origin  \
# 0  AAY2839        A320          Norfolk Intl (KORF)
# 1   AAY411        A320  Fort Lauderdale Intl (KFLL)
# 2   ABY552        A320   Sharjah Int'l (SHJ / OMSJ)
#
#                                          Destination Departure Date  \
# 0                        Orlando Sanford Intl (KSFB)     04.03.2024
# 1  Cincinnati/Northern Kentucky International Air...     04.03.2024
# 2                         Sialkot Int'l (SKT / OPST)     05.03.2024
#
#     Departure Time Arrival Date     Arrival Time Estimated Arrival Time  \
# 0  Mon 03:21PM EST   04.03.2024  Mon 05:01PM EST               01:32:00
# 1  Mon 03:21PM EST   04.03.2024  Mon 05:48PM EST               02:23:00
# 2  Tue 12:22AM +04   05.03.2024  Tue 03:57AM PKT               02:35:00
#
#   RealArrivalTime Departure_Time Arrival_Time
# 0          2h 02m        03:21PM      05:01PM
# 1          2h 52m        03:21PM      05:48PM
# 2          2h 45m        12:22AM      03:57AM

# %%
df = df.drop(columns=['Departure Time', 'Arrival Time'])
df
# Out:
#     Aircraft Flight Type                                        Origin  \
# 0    AAY2839        A320                           Norfolk Intl (KORF)
# 1     AAY411        A320                   Fort Lauderdale Intl (KFLL)
# 2     ABY552        A320                    Sharjah Int'l (SHJ / OMSJ)
# 3    AFR1384        A320         Charles de Gaulle/Roissy (CDG / LFPG)
# 4    AFR1748        A320         Charles de Gaulle/Roissy (CDG / LFPG)
# ..       ...         ...                                           ...
# 486   RZO175        A320                   Porto / Oporto (OPO / LPPR)
# 487  VOI1035        A320  Mexico City Santa Lucía Airport (NLU / MMSM)
# 488   VOI499        A320       Del Bajio Guanajuato Int'l (BJX / MMLO)
# 489   VOI924        A320    Lic. Jesus Teran Peredo Int'l (AGU / MMAS)
# 490   VOI967        A320                        Harry Reid Intl (KLAS)
#
#                                            Destination Departure Date  \
# 0                          Orlando Sanford Intl (KSFB)     04.03.2024
# 1    Cincinnati/Northern Kentucky International Air...     04.03.2024
# 2                           Sialkot Int'l (SKT / OPST)     05.03.2024
# 3                    Tunis-Carthage Int'l (TUN / DTTA)     04.03.2024
# 4                                  Malaga (AGP / LEMG)     04.03.2024
# ..                                                 ...            ...
# 486           Ponta Delgada Joao Paulo II (PDL / LPPD)     09.03.2024
# 487   Don Miguel Hidalgo y Costilla Int'l (GDL / MMGL)     09.03.2024
# 488   General Abelardo L. Rodriguez Int'l (TIJ / MMTJ)     09.03.2024
# 489                            Los Angeles Intl (KLAX)     09.03.2024
# 490              Lic. Benito Juarez Int'l (MEX / MMMX)     09.03.2024
#
#     Arrival Date Estimated Arrival Time RealArrivalTime Departure_Time  \
# 0     2024-04-03               01:32:00          2h 02m        03:21PM
# 1     2024-04-03               02:23:00          2h 52m        03:21PM
# 2     2024-05-03               02:35:00          2h 45m        12:22AM
# 3     2024-04-03               02:07:00          2h 23m        09:21PM
# 4     2024-04-03               02:29:00          2h 49m        09:20PM
# ..           ...                    ...             ...            ...
# 486   2024-09-03               02:10:00          2h 30m        10:04PM
# 487   2024-09-03               01:09:00          1h 19m        04:06PM
# 488   2024-09-03               02:47:00          3h 11m        04:04PM
# 489   2024-09-03               02:40:00          3h 00m        04:05PM
# 490   2024-09-03               03:17:00          3h 53m        02:04PM
#
#     Arrival_Time
# 0        05:01PM
# 1        05:48PM
# 2        03:57AM
# 3        11:29PM
# 4        11:51PM
# ..           ...
# 486      11:15PM
# 487      05:15PM
# 488      04:54PM
# 489      04:45PM
# 490      07:25PM
#
# [489 rows x 10 columns]

# %%
df = df[['Aircraft','Flight Type','Origin',
'Destination', 'Departure Date', 'Departure_Time', 'Arrival Date', 'Arrival_Time', 'Estimated Arrival Time', 'RealArrivalTime']]
df
# Out:
#     Aircraft Flight Type                                        Origin  \
# 0    AAY2839        A320                           Norfolk Intl (KORF)
# 1     AAY411        A320                   Fort Lauderdale Intl (KFLL)
# 2     ABY552        A320                    Sharjah Int'l (SHJ / OMSJ)
# 3    AFR1384        A320         Charles de Gaulle/Roissy (CDG / LFPG)
# 4    AFR1748        A320         Charles de Gaulle/Roissy (CDG / LFPG)
# ..       ...         ...                                           ...
# 486   RZO175        A320                   Porto / Oporto (OPO / LPPR)
# 487  VOI1035        A320  Mexico City Santa Lucía Airport (NLU / MMSM)
# 488   VOI499        A320       Del Bajio Guanajuato Int'l (BJX / MMLO)
# 489   VOI924        A320    Lic. Jesus Teran Peredo Int'l (AGU / MMAS)
# 490   VOI967        A320                        Harry Reid Intl (KLAS)
#
#                                            Destination Departure Date  \
# 0                          Orlando Sanford Intl (KSFB)     04.03.2024
# 1    Cincinnati/Northern Kentucky International Air...     04.03.2024
# 2                           Sialkot Int'l (SKT / OPST)     05.03.2024
# 3                    Tunis-Carthage Int'l (TUN / DTTA)     04.03.2024
# 4                                  Malaga (AGP / LEMG)     04.03.2024
# ..                                                 ...            ...
# 486           Ponta Delgada Joao Paulo II (PDL / LPPD)     09.03.2024
# 487   Don Miguel Hidalgo y Costilla Int'l (GDL / MMGL)     09.03.2024
# 488   General Abelardo L. Rodriguez Int'l (TIJ / MMTJ)     09.03.2024
# 489                            Los Angeles Intl (KLAX)     09.03.2024
# 490              Lic. Benito Juarez Int'l (MEX / MMMX)     09.03.2024
#
#     Departure_Time Arrival Date Arrival_Time Estimated Arrival Time  \
# 0          03:21PM   04.03.2024      05:01PM               01:32:00
# 1          03:21PM   04.03.2024      05:48PM               02:23:00
# 2          12:22AM   05.03.2024      03:57AM               02:35:00
# 3          09:21PM   04.03.2024      11:29PM               02:07:00
# 4          09:20PM   04.03.2024      11:51PM               02:29:00
# ..             ...          ...          ...                    ...
# 486        10:04PM   09.03.2024      11:15PM               02:10:00
# 487        04:06PM   09.03.2024      05:15PM               01:09:00
# 488        04:04PM   09.03.2024      04:54PM               02:47:00
# 489        04:05PM   09.03.2024      04:45PM               02:40:00
# 490        02:04PM   09.03.2024      07:25PM               03:17:00
#
#     RealArrivalTime
# 0            2h 02m
# 1            2h 52m
# 2            2h 45m
# 3            2h 23m
# 4            2h 49m
# ..              ...
# 486          2h 30m
# 487          1h 19m
# 488          3h 11m
# 489          3h 00m
# 490          3h 53m
#
# [491 rows x 10 columns]

# %%
# Out:
#     Aircraft Flight Type                                             Origin  \
# 243  AFL1386        A320                               Near Nizhny Novgorod
# 335   FHY988        A320          Adolfo Suárez Madrid-Barajas (MAD / LEMD)
# 420  JAP7780        A320                    Jorge Chávez Int'l (LIM / SPJC)
# 444  AEE6005        A320         Thessaloniki Int'l, Makedonia (SKG / LGTS)
# 449  BIX2517        A320                    Gran Canaria Int'l (LPA / GCLP)
# 457    LAN13        A320  Comodoro Arturo Merino Benitez Int'l (SCL / SCEL)
# 458   N230AC        A320                          Los Garzones (MTR / SKMR)
# 478  GLG1639        A320          Jose Joaquin de Olmedo Int'l (GYE / SEGU)
# 479  JAP7294        A320                    Jorge Chávez Int'l (LIM / SPJC)
#
#     Destination Departure Date Departure_Time Arrival Date Arrival_Time  \
# 243         NaN     07.03.2024        11:53AM         None          NaN
# 335         NaN     08.03.2024        11:38AM         None          NaN
# 420         NaN     09.03.2024        03:09PM         None          NaN
# 444         NaN     09.03.2024        11:00PM         None          NaN
# 449         NaN     09.03.2024        09:01PM         None          NaN
# 457         NaN     09.03.2024        06:01PM         None          NaN
# 458         NaN     09.03.2024        04:00PM         None          NaN
# 478         NaN     09.03.2024        05:06PM         None          NaN
# 479         NaN     09.03.2024        05:05PM         None          NaN
#
#     Estimated Arrival Time RealArrivalTime
# 243                    NaN          0h 05m
# 335                    NaN          0h 06m
# 420                    NaN          0h 07m
# 444                    NaN          0h 12m
# 449                    NaN          0h 11m
# 457                    NaN          0h 12m
# 458                    NaN          0h 11m
# 478                    NaN          0h 04m
# 479                    NaN          0h 05m

# %%
df.shape
# Out:
# (490, 10)

# %%
# Convert "Estimated Arrival Time" to minutes
df['Estimated Arrival Time'] = pd.to_timedelta(df['Estimated Arrival Time'])
df['EA_Time_Minutes'] = df['Estimated Arrival Time'].dt.total_seconds() / 60
# Print the result DataFrame
# Out:
# /tmp/ipykernel_28651/4248053022.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Estimated Arrival Time'] = pd.to_timedelta(df['Estimated Arrival Time'])
# /tmp/ipykernel_28651/4248053022.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['EA_Time_Minutes'] = df['Estimated Arrival Time'].dt.total_seconds() / 60

# %%
df
# Out:
#     Aircraft Flight Type                                        Origin  \
# 0    AAY2839        A320                           Norfolk Intl (KORF)
# 1     AAY411        A320                   Fort Lauderdale Intl (KFLL)
# 2     ABY552        A320                    Sharjah Int'l (SHJ / OMSJ)
# 3    AFR1384        A320         Charles de Gaulle/Roissy (CDG / LFPG)
# 4    AFR1748        A320         Charles de Gaulle/Roissy (CDG / LFPG)
# ..       ...         ...                                           ...
# 486   RZO175        A320                   Porto / Oporto (OPO / LPPR)
# 487  VOI1035        A320  Mexico City Santa Lucía Airport (NLU / MMSM)
# 488   VOI499        A320       Del Bajio Guanajuato Int'l (BJX / MMLO)
# 489   VOI924        A320    Lic. Jesus Teran Peredo Int'l (AGU / MMAS)
# 490   VOI967        A320                        Harry Reid Intl (KLAS)
#
#                                            Destination Departure Date  \
# 0                          Orlando Sanford Intl (KSFB)     04.03.2024
# 1    Cincinnati/Northern Kentucky International Air...     04.03.2024
# 2                           Sialkot Int'l (SKT / OPST)     05.03.2024
# 3                    Tunis-Carthage Int'l (TUN / DTTA)     04.03.2024
# 4                                  Malaga (AGP / LEMG)     04.03.2024
# ..                                                 ...            ...
# 486           Ponta Delgada Joao Paulo II (PDL / LPPD)     09.03.2024
# 487   Don Miguel Hidalgo y Costilla Int'l (GDL / MMGL)     09.03.2024
# 488   General Abelardo L. Rodriguez Int'l (TIJ / MMTJ)     09.03.2024
# 489                            Los Angeles Intl (KLAX)     09.03.2024
# 490              Lic. Benito Juarez Int'l (MEX / MMMX)     09.03.2024
#
#     Departure_Time Arrival Date Arrival_Time Estimated Arrival Time  \
# 0          03:21PM   04.03.2024      05:01PM        0 days 01:32:00
# 1          03:21PM   04.03.2024      05:48PM        0 days 02:23:00
# 2          12:22AM   05.03.2024      03:57AM        0 days 02:35:00
# 3          09:21PM   04.03.2024      11:29PM        0 days 02:07:00
# 4          09:20PM   04.03.2024      11:51PM        0 days 02:29:00
# ..             ...          ...          ...                    ...
# 486        10:04PM   09.03.2024      11:15PM        0 days 02:10:00
# 487        04:06PM   09.03.2024      05:15PM        0 days 01:09:00
# 488        04:04PM   09.03.2024      04:54PM        0 days 02:47:00
# 489        04:05PM   09.03.2024      04:45PM        0 days 02:40:00
# 490        02:04PM   09.03.2024      07:25PM        0 days 03:17:00
#
#     RealArrivalTime  EA_Time_Minutes
# 0            2h 02m             92.0
# 1            2h 52m            143.0
# 2            2h 45m            155.0
# 3            2h 23m            127.0
# 4            2h 49m            149.0
# ..              ...              ...
# 486          2h 30m            130.0
# 487          1h 19m             69.0
# 488          3h 11m            167.0
# 489          3h 00m            160.0
# 490          3h 53m            197.0
#
# [490 rows x 11 columns]

# %%
# Convert "RealArrivalTime" to minutes
df['RA_Time_Minutes'] = df['RealArrivalTime'].apply(lambda x: sum(int(i[:-1]) * (60 if i.endswith('h') else 1) for i in x.split()))



# Display the DataFrame
df
# Out:
# /tmp/ipykernel_28651/4069838015.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['RA_Time_Minutes'] = df['RealArrivalTime'].apply(lambda x: sum(int(i[:-1]) * (60 if i.endswith('h') else 1) for i in x.split()))
#     Aircraft Flight Type                                        Origin  \
# 0    AAY2839        A320                           Norfolk Intl (KORF)
# 1     AAY411        A320                   Fort Lauderdale Intl (KFLL)
# 2     ABY552        A320                    Sharjah Int'l (SHJ / OMSJ)
# 3    AFR1384        A320         Charles de Gaulle/Roissy (CDG / LFPG)
# 4    AFR1748        A320         Charles de Gaulle/Roissy (CDG / LFPG)
# ..       ...         ...                                           ...
# 486   RZO175        A320                   Porto / Oporto (OPO / LPPR)
# 487  VOI1035        A320  Mexico City Santa Lucía Airport (NLU / MMSM)
# 488   VOI499        A320       Del Bajio Guanajuato Int'l (BJX / MMLO)
# 489   VOI924        A320    Lic. Jesus Teran Peredo Int'l (AGU / MMAS)
# 490   VOI967        A320                        Harry Reid Intl (KLAS)
#
#                                            Destination Departure Date  \
# 0                          Orlando Sanford Intl (KSFB)     04.03.2024
# 1    Cincinnati/Northern Kentucky International Air...     04.03.2024
# 2                           Sialkot Int'l (SKT / OPST)     05.03.2024
# 3                    Tunis-Carthage Int'l (TUN / DTTA)     04.03.2024
# 4                                  Malaga (AGP / LEMG)     04.03.2024
# ..                                                 ...            ...
# 486           Ponta Delgada Joao Paulo II (PDL / LPPD)     09.03.2024
# 487   Don Miguel Hidalgo y Costilla Int'l (GDL / MMGL)     09.03.2024
# 488   General Abelardo L. Rodriguez Int'l (TIJ / MMTJ)     09.03.2024
# 489                            Los Angeles Intl (KLAX)     09.03.2024
# 490              Lic. Benito Juarez Int'l (MEX / MMMX)     09.03.2024
#
#     Departure_Time Arrival Date Arrival_Time Estimated Arrival Time  \
# 0          03:21PM   04.03.2024      05:01PM        0 days 01:32:00
# 1          03:21PM   04.03.2024      05:48PM        0 days 02:23:00
# 2          12:22AM   05.03.2024      03:57AM        0 days 02:35:00
# 3          09:21PM   04.03.2024      11:29PM        0 days 02:07:00
# 4          09:20PM   04.03.2024      11:51PM        0 days 02:29:00
# ..             ...          ...          ...                    ...
# 486        10:04PM   09.03.2024      11:15PM        0 days 02:10:00
# 487        04:06PM   09.03.2024      05:15PM        0 days 01:09:00
# 488        04:04PM   09.03.2024      04:54PM        0 days 02:47:00
# 489        04:05PM   09.03.2024      04:45PM        0 days 02:40:00
# 490        02:04PM   09.03.2024      07:25PM        0 days 03:17:00
#
#     RealArrivalTime  EA_Time_Minutes  RA_Time_Minutes
# 0            2h 02m             92.0              122
# 1            2h 52m            143.0              172
# 2            2h 45m            155.0              165
# 3            2h 23m            127.0              143
# 4            2h 49m            149.0              169
# ..              ...              ...              ...
# 486          2h 30m            130.0              150
# 487          1h 19m             69.0               79
# 488          3h 11m            167.0              191
# 489          3h 00m            160.0              180
# 490          3h 53m            197.0              233
#
# [490 rows x 12 columns]

# %%
df['Delay_Time'] = df['RA_Time_Minutes'] - df['EA_Time_Minutes']
# Out:
# /tmp/ipykernel_28651/3463165877.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Delay_Time'] = df['RA_Time_Minutes'] - df['EA_Time_Minutes']

# %%
df
# Out:
#     Aircraft Flight Type                                        Origin  \
# 0    AAY2839        A320                           Norfolk Intl (KORF)
# 1     AAY411        A320                   Fort Lauderdale Intl (KFLL)
# 2     ABY552        A320                    Sharjah Int'l (SHJ / OMSJ)
# 3    AFR1384        A320         Charles de Gaulle/Roissy (CDG / LFPG)
# 4    AFR1748        A320         Charles de Gaulle/Roissy (CDG / LFPG)
# ..       ...         ...                                           ...
# 486   RZO175        A320                   Porto / Oporto (OPO / LPPR)
# 487  VOI1035        A320  Mexico City Santa Lucía Airport (NLU / MMSM)
# 488   VOI499        A320       Del Bajio Guanajuato Int'l (BJX / MMLO)
# 489   VOI924        A320    Lic. Jesus Teran Peredo Int'l (AGU / MMAS)
# 490   VOI967        A320                        Harry Reid Intl (KLAS)
#
#                                            Destination Departure Date  \
# 0                          Orlando Sanford Intl (KSFB)     04.03.2024
# 1    Cincinnati/Northern Kentucky International Air...     04.03.2024
# 2                           Sialkot Int'l (SKT / OPST)     05.03.2024
# 3                    Tunis-Carthage Int'l (TUN / DTTA)     04.03.2024
# 4                                  Malaga (AGP / LEMG)     04.03.2024
# ..                                                 ...            ...
# 486           Ponta Delgada Joao Paulo II (PDL / LPPD)     09.03.2024
# 487   Don Miguel Hidalgo y Costilla Int'l (GDL / MMGL)     09.03.2024
# 488   General Abelardo L. Rodriguez Int'l (TIJ / MMTJ)     09.03.2024
# 489                            Los Angeles Intl (KLAX)     09.03.2024
# 490              Lic. Benito Juarez Int'l (MEX / MMMX)     09.03.2024
#
#     Departure_Time Arrival Date Arrival_Time Estimated Arrival Time  \
# 0          03:21PM   04.03.2024      05:01PM        0 days 01:32:00
# 1          03:21PM   04.03.2024      05:48PM        0 days 02:23:00
# 2          12:22AM   05.03.2024      03:57AM        0 days 02:35:00
# 3          09:21PM   04.03.2024      11:29PM        0 days 02:07:00
# 4          09:20PM   04.03.2024      11:51PM        0 days 02:29:00
# ..             ...          ...          ...                    ...
# 486        10:04PM   09.03.2024      11:15PM        0 days 02:10:00
# 487        04:06PM   09.03.2024      05:15PM        0 days 01:09:00
# 488        04:04PM   09.03.2024      04:54PM        0 days 02:47:00
# 489        04:05PM   09.03.2024      04:45PM        0 days 02:40:00
# 490        02:04PM   09.03.2024      07:25PM        0 days 03:17:00
#
#     RealArrivalTime  EA_Time_Minutes  RA_Time_Minutes  Delay_Time
# 0            2h 02m             92.0              122        30.0
# 1            2h 52m            143.0              172        29.0
# 2            2h 45m            155.0              165        10.0
# 3            2h 23m            127.0              143        16.0
# 4            2h 49m            149.0              169        20.0
# ..              ...              ...              ...         ...
# 486          2h 30m            130.0              150        20.0
# 487          1h 19m             69.0               79        10.0
# 488          3h 11m            167.0              191        24.0
# 489          3h 00m            160.0              180        20.0
# 490          3h 53m            197.0              233        36.0
#
# [490 rows x 13 columns]

# %%
df.to_csv("Final-data.csv")
